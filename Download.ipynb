# %% [markdown]
# <a href="https://colab.research.google.com/github/santhiya-hds5210/ORES-5160-EDA/blob/main/Download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


def read_csv_or_excel(file_path):
    """
    Reads a CSV or Excel file based on the file extension.

    Args:
        file_path (str): The path to the CSV or Excel file.

    Returns:
        pd.DataFrame: A Pandas DataFrame containing the data from the file.
        >>> read_csv_or_excel(file_path)
        >>> us_county
        if incase its a wrong file
        >>> read_csv_or_excel(file_path)
        >>> This file format is incorrect. Please provide a CSV or Excel file.
    """
    if file_path.endswith('.csv'):
        # This is the part where it tries to read a CSV file
        df = pd.read_csv(file_path)
    elif file_path.endswith('.xlsx'):
        # This is the part where it tries to read a Excel file
        df = pd.read_excel(file_path)
    else:
        #This is the exception handling that I have kept
        raise ValueError("This file format is incorrect. Please provide a CSV or Excel file.")

    return df

file_path = '/content/us_county.csv'
data_frame = read_csv_or_excel(file_path)
print(data_frame)
# Out:
#        fips               county        state state_code    male  female  \
# 0      1001       Autauga County      Alabama         AL   26874   28326
# 1      1003       Baldwin County      Alabama         AL  101188  106919
# 2      1005       Barbour County      Alabama         AL   13697   12085
# 3      1007          Bibb County      Alabama         AL   12152   10375
# 4      1009        Blount County      Alabama         AL   28434   29211
# ...     ...                  ...          ...        ...     ...     ...
# 3215  72145  Vega Baja Municipio  Puerto Rico        NaN   25580   27791
# 3216  72147    Vieques Municipio  Puerto Rico        NaN    4332    4439
# 3217  72149   Villalba Municipio  Puerto Rico        NaN   11169   11824
# 3218  72151    Yabucoa Municipio  Puerto Rico        NaN   16541   17608
# 3219  72153      Yauco Municipio  Puerto Rico        NaN   17475   18964
#
#       median_age  population  female_percentage        lat       long
# ...

# %%
import matplotlib.pyplot as plt

# Assuming you want to create a boxplot for a specific column
data_to_plot = data_frame['population']

# Create a boxplot
plt.boxplot(data_to_plot)

# Add labels and title
plt.xlabel('X-axis male')
plt.ylabel('Y-axis female')
plt.title('Boxplot for ' + 'population')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
file_path = '/content/us_county.csv'  # Replace with the path to your CSV or Excel file
data_frame = read_csv_or_excel(file_path)

# Assuming you have two columns 'X' and 'Y' in your DataFrame
x = data_frame['male']
y = data_frame['female']

# Create a scatter plot
plt.scatter(x, y)

# Add labels and title
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Scatter Plot')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'population' is a numerical column in your DataFrame
data_to_plot = data_frame['population']

# Create a histogram for population data
plt.hist(data_to_plot, bins=100)  # You can adjust the number of bins as needed

# Add labels and title
plt.xlabel('male')
plt.ylabel('female')
plt.title('Histogram of Population Data')

# Display the plot
plt.show()

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
data_frame.shape
# Out:
# (3220, 11)

# %%
data_frame.head()
# Out:
#    fips          county    state state_code    male  female  median_age  \
# 0  1001  Autauga County  Alabama         AL   26874   28326        37.8
# 1  1003  Baldwin County  Alabama         AL  101188  106919        42.8
# 2  1005  Barbour County  Alabama         AL   13697   12085        39.9
# 3  1007     Bibb County  Alabama         AL   12152   10375        39.9
# 4  1009   Blount County  Alabama         AL   28434   29211        40.8
#
#    population  female_percentage        lat       long
# 0       55200          51.315217  32.534923 -86.642730
# 1      208107          51.376936  30.727479 -87.722564
# 2       25782          46.873788  31.869581 -85.393210
# 3       22527          46.055844  32.998628 -87.126475
# 4       57645          50.673953  33.980869 -86.567380

# %%
data_frame.tail()
# Out:
#        fips               county        state state_code   male  female  \
# 3215  72145  Vega Baja Municipio  Puerto Rico        NaN  25580   27791
# 3216  72147    Vieques Municipio  Puerto Rico        NaN   4332    4439
# 3217  72149   Villalba Municipio  Puerto Rico        NaN  11169   11824
# 3218  72151    Yabucoa Municipio  Puerto Rico        NaN  16541   17608
# 3219  72153      Yauco Municipio  Puerto Rico        NaN  17475   18964
#
#       median_age  population  female_percentage        lat       long
# 3215        40.7       53371          52.071350  18.428461 -66.397926
# 3216        43.6        8771          50.609965  18.122662 -65.439095
# 3217        38.8       22993          51.424347  18.128155 -66.472816
# 3218        42.5       34149          51.562271  18.070468 -65.896311
# 3219        43.0       36439          52.043141  18.079728 -66.858276

# %%
data_frame.tail(7)
# Out:
#        fips               county        state state_code   male  female  \
# 3213  72141     Utuado Municipio  Puerto Rico        NaN  14279   15123
# 3214  72143  Vega Alta Municipio  Puerto Rico        NaN  18044   19680
# 3215  72145  Vega Baja Municipio  Puerto Rico        NaN  25580   27791
# 3216  72147    Vieques Municipio  Puerto Rico        NaN   4332    4439
# 3217  72149   Villalba Municipio  Puerto Rico        NaN  11169   11824
# 3218  72151    Yabucoa Municipio  Puerto Rico        NaN  16541   17608
# 3219  72153      Yauco Municipio  Puerto Rico        NaN  17475   18964
#
#       median_age  population  female_percentage        lat       long
# 3213        42.8       29402          51.435277  18.271019 -66.702473
# 3214        38.6       37724          52.168381  18.409479 -66.337210
# 3215        40.7       53371          52.071350  18.428461 -66.397926
# 3216        43.6        8771          50.609965  18.122662 -65.439095
# ...

# %%
print(data_frame["male"].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0        26874
# 1       101188
# 2        13697
# 3        12152
# 4        28434
#          ...
# 3215     25580
# 3216      4332
# 3217     11169
# 3218     16541
# 3219     17475
# Name: male, Length: 3220, dtype: int64>

# %%
print(data_frame["female"].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0        28326
# 1       106919
# 2        12085
# 3        10375
# 4        29211
#          ...
# 3215     27791
# 3216      4439
# 3217     11824
# 3218     17608
# 3219     18964
# Name: female, Length: 3220, dtype: int64>

# %%
print(data_frame['population'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0        55200
# 1       208107
# 2        25782
# 3        22527
# 4        57645
#          ...
# 3215     53371
# 3216      8771
# 3217     22993
# 3218     34149
# 3219     36439
# Name: population, Length: 3220, dtype: int64>
